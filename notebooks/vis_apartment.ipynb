# %% [markdown]
# ## Visualize IoT Data

# %%
import pandas as pd
df = pd.read_csv("../data/synthetic_sensors.csv", parse_dates=["timestamp"])

# %% [markdown]
# Visualize two people behaviour in specific day

# %%
# Plot the states for day X
from visualization import plot_person_states
day_number = 11
plot_person_states(day_number, df["timestamp"], df["person1_inside"], df["person1_sleeping"], df["person1_room1_state"],df["person1_window_state"],df["person1_door_state"],
                   state_labels=["Person1 - Inside", "Person1 - Sleeping", "Person1 - In Room 1", "Person1 - Window State", "Person1 - Door State"])   
plot_person_states(day_number, df["timestamp"], df["person2_inside"], df["person2_sleeping"], df["person2_room1_state"],df["person2_window_state"],df["person2_door_state"],
                   state_labels=["Person2 - Inside", "Person2 - Sleeping", "Person2 - In Room 1", "Person2 - Window State", "Person2 - Door State"])

# %%
plot_person_states(day_number, df["timestamp"], df["sensor_window"],df["person1_window_state"], df["person2_window_state"],
                   state_labels=["Apartment - Windows State", "Person 1 - Window State", "Person 2 - Window State"])
plot_person_states(day_number, df["timestamp"], df["sensor_door"],df["person1_door_state"], df["person2_door_state"],
                   state_labels=["Apartment - Doors State", "Person 1 - Door State", "Person 2 - Door State"])


plot_person_states(day_number, df["timestamp"], df["person1_room1_state"],df["person2_room1_state"],
                   state_labels=["Person 1 - In Room 1", "Person 2 - In Room 1"])

plot_person_states(day_number, df["timestamp"], df["sensor_motion"],df["person1_room1_state"], df["person2_room1_state"],
                   state_labels=["Apartment - Motion", "Person 1 - In Room 1", "Person 2 - In Room 1"])
